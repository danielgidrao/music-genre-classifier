# %% [markdown]
# # 02 - Training Models (Caminho B)
#
# Este notebook executa o pipeline principal com extração via `librosa` e treino supervisionado.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
sys.path.append(str(PROJECT_ROOT / 'src'))

# %%
from extract_features import build_feature_dataset

# Extrai features dos audios do fma_small (pode demorar)
df = build_feature_dataset()
df.head()

# %%
# Alternativa: execute no terminal
# !python ../src/train.py

# %%
# Alternativa: execute no terminal
# !python ../src/evaluate.py

# %%
import pandas as pd
from config import TRAIN_RESULTS_CSV

if TRAIN_RESULTS_CSV.exists():
    display(pd.read_csv(TRAIN_RESULTS_CSV))
else:
    print('Treine os modelos primeiro para ver a comparação.')
